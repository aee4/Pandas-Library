# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Use of matplotlib helps us to visualize our data

# %%
movies = pd.read_csv("C:\\Users\\lenovo\\Desktop\\BUILD\\Machine Learning\\Pandas\\movies.csv", low_memory= False)
sample = movies.head(15)
sample
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   False                                                NaN  65000000
# 2   False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   False                                                NaN  16000000
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5   False                                                NaN  60000000
# 6   False                                                NaN  58000000
# 7   False                                                NaN         0
# 8   False                                                NaN  35000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10  False                                                NaN  62000000
# 11  False                                                NaN         0
# ...

# %%
sample.plot

# %%
#the x and y values represent thr name and age and the kind represent the type of graph
#kind = 'area','bar','barh','box','density','hexbin','hist','kde','line','pie','scatter'
sample.plot(x="original_title", y="vote_average", kind="barh")
# Out:
# <Axes: ylabel='original_title'>

# %%
#we can plot just columns too
sample["vote_count"].plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#comparing two columns 
sample.plot.area(x= "budget", y="revenue")
# Out:
# <Axes: xlabel='budget'>

# %%
#Using subplots
#gives several columns data 
fig = sample.plot.area(figsize=(12, 4), subplots=True)
