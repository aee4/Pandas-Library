# %%
import pandas as pd

# %%
movies = pd.read_csv("C:\\Users\\lenovo\\Desktop\\BUILD\\Machine Learning\\Pandas\\movies.csv",low_memory= False)

# %%
#selecting subsets of a dataframe

movies["title"]
# Out:
# 0                          Toy Story
# 1                            Jumanji
# 2                   Grumpier Old Men
# 3                  Waiting to Exhale
# 4        Father of the Bride Part II
#                     ...
# 45461                         Subdue
# 45462            Century of Birthing
# 45463                       Betrayal
# 45464               Satan Triumphant
# 45465                       Queerama
# Name: title, Length: 45466, dtype: object

# %%
#the selected column is a series, we can check using
type(movies["title"])
# Out:
# pandas.core.series.Series

# %%
#we can make a DataFrame subset out of the original too
#output dataset is just a dataframe(2 columns) of genres and movie titles
title_genre = movies[["genres","original_title"]]
title_genre
# Out:
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                     original_title
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# ...

# %%
#creating subset dataFrames based of conditions
#we can use  ==, !=, <, <=,| and some functions like isin()
runtime_gt_80 = movies[movies["runtime"] > 80]
runtime_gt_80.head(5)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %% [markdown]
# # we can combine multiple conditions using "and" and "or" operators
# # we can also use parentheses to group conditions
# # we can use the "not" operator to negate a condition
# # we can use the "in" operator to check if a value is in a list or a
# # we can use the "not in" operator to check if a value is not in a list
# # we can use the "is" operator to check if two values are the same object

# %%
runtime_gt80_vote_average_gt7 = movies[(movies["runtime"] > 80) | (movies["vote_average"] > 7.0)]
runtime_gt80_vote_average_gt7.tail(4)
# Out:
#        adult belongs_to_collection budget  \
# 45461  False                   NaN      0
# 45462  False                   NaN      0
# 45463  False                   NaN      0
# 45464  False                   NaN      0
#
#                                                   genres  \
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
#
#                                    homepage      id    imdb_id  \
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
#
#       original_language       original_title  \
# 45461                fa              رگ خواب
# 45462                tl  Siglo ng Pagluluwal
# ...
